# %%
# Define product descriptions and prices
lovely_loveseat_description = "Lovely Loveseat. A tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep. Red or white."
lovely_loveseat_price = 354.00

stylish_settee_description = "Stylish Settee. Faux leather on birch. 29.50 inches high x 54.75 inches wide x 28 inches deep. Black."
stylish_settee_price = 280.50

luxurious_lamp_description = "Luxurious Lamp. Glass and iron. 36 inches tall. Brown with cream shade."
luxurious_lamp_price = 73.15

# Define the sales tax
sales_tax = 0.018

# Initialize customer variables
customer_one_total = 0
customer_one_itemisation = ""

# Customer One shopping
customer_one_total += lovely_loveseat_price
customer_one_itemisation += lovely_loveseat_description + "\n"  # Include line breaks for readability

customer_one_total += luxurious_lamp_price
customer_one_itemisation += luxurious_lamp_description + "\n"

# Calculate tax and total for Customer One
customer_one_tax = customer_one_total * sales_tax
customer_one_total += customer_one_tax

# Display Customer One's shopping and total
print("Customer One Items:")
print(customer_one_itemisation)
print("Customer One Total: £{:.2f}".format(customer_one_total))  # Format the total as currency

# Add a blank line to create a paragraph space
print("\n")

# Initialize customer variables for Customer Two
customer_two_total = 0
customer_two_itemisation = ""

# Customer Two shopping
customer_two_total += stylish_settee_price
customer_two_itemisation += stylish_settee_description + "\n"

customer_two_total += luxurious_lamp_price
customer_two_itemisation += luxurious_lamp_description + "\n"

# Calculate tax and total for Customer Two
customer_two_tax = customer_two_total * sales_tax
customer_two_total += customer_two_tax

# Display Customer Two's shopping and total
print("Customer Two Items:")
print(customer_two_itemisation)
print("Customer Two Total: £{:.2f}".format(customer_two_total))  # Format the total as currency

# Add a blank line to create a paragraph space
print("\n")

# Describe the code
catalogue_description = "This code creates a catalogue and processes customer orders, calculating totals and taxes."
print("Catalogue Description:")
print( catalogue_description)
# Out:
# Customer One Items:
# Lovely Loveseat. A tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep. Red or white.
# Luxurious Lamp. Glass and iron. 36 inches tall. Brown with cream shade.
#
# Customer One Total: £434.84
#
#
# Customer Two Items:
# Stylish Settee. Faux leather on birch. 29.50 inches high x 54.75 inches wide x 28 inches deep. Black.
# Luxurious Lamp. Glass and iron. 36 inches tall. Brown with cream shade.
#
# Customer Two Total: £360.02
#
#
# Catalogue Description:
# This code creates a catalogue and processes customer orders, calculating totals and taxes.
